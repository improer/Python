# %%
import pandas as pd
import numpy as np
import csv
import xlsxwriter
from csv import reader, writer
from openpyxl import Workbook
import datetime as dt

# %%
#Import mobile route info
cs = "geoshortie.csv"
df= pd.read_csv(cs)
df.head(2)
# Out:
#         date       slx_id        slx_driver   truck  ship_to  \
# 0   5/5/2022  D0000224071    Jerry Isaacson  JUB007  71960_3
# 1  5/16/2022  D0000224757  Mason Valenzuela  JUB251  71960_3
#
#                 customer        address        city_st_zip  fills  product  \
# 0  B & B Leasing-Mollala  508 Shaver St  MOLALLA, OR 97038     15       82
# 1  B & B Leasing-Mollala  508 Shaver St  MOLALLA, OR 97038     11       82
#
#    margin  gallons  fee   profit                     zone       driver  \
# 0   0.449      278    0  124.822  B & B Leasing - Mollala    jisaacson
# 1   0.449      350    0  157.150  B & B Leasing - Mollala  mvalenzuela
#
#     distance  total_hours  profit_per_hour
# 0  17.861516         0.25       499.288000
# 1  22.390688         0.85       184.882353

# %%
fresh =df.groupby('customer').agg({'total_hours':'median'})
fresh.rename({'total_hours': 'median'}, axis=1, inplace=True)

# %%
result = pd.merge(df,
                 fresh,
                 on='customer')

freed = result
freed.head()
# Out:
#         date       slx_id        slx_driver   truck  ship_to  \
# 0   5/5/2022  D0000224071    Jerry Isaacson  JUB007  71960_3
# 1  5/16/2022  D0000224757  Mason Valenzuela  JUB251  71960_3
# 2  5/17/2022  D0000224829    Jerry Isaacson  JUB003  71960_3
# 3  5/19/2022  D0000225286    Jerry Isaacson  JUB003  71960_3
# 4   5/5/2022  D0000224066    Jerry Isaacson  JUB007  71960_2
#
#                     customer          address            city_st_zip  fills  \
# 0      B & B Leasing-Mollala    508 Shaver St      MOLALLA, OR 97038     15
# 1      B & B Leasing-Mollala    508 Shaver St      MOLALLA, OR 97038     11
# 2      B & B Leasing-Mollala    508 Shaver St      MOLALLA, OR 97038      7
# 3      B & B Leasing-Mollala    508 Shaver St      MOLALLA, OR 97038     12
# 4  B & B Leasing-Oregon City  322 Morton Road  Oregon City, OR 97015     18
#
#    product  margin  gallons  fee   profit                         zone  \
# 0       82   0.449      278    0  124.822      B & B Leasing - Mollala
# 1       82   0.449      350    0  157.150      B & B Leasing - Mollala
# 2       82   0.449      261    0  117.189      B & B Leasing - Mollala
# 3       82   0.449      305    0  136.945      B & B Leasing - Mollala
# 4       82   0.449      480    0  215.520  B & B Leasing - Oregon City
#
#         driver   distance  total_hours  profit_per_hour  median
# 0    jisaacson  17.861516     0.250000       499.288000    0.45
# 1  mvalenzuela  22.390688     0.850000       184.882353    0.45
# 2    jisaacson  17.809591     0.350000       334.825714    0.45
# 3    jisaacson  17.862590     0.550000       248.990909    0.45
# 4    jisaacson   5.992708     0.833333       258.624000    0.80

# %%
highs = freed.query('total_hours > median*2')

# %%
lows = freed.query('total_hours < median/2')

# %%
mix = pd.concat([highs, lows], join="inner")

# %%
mix.to_csv('lowhigh.csv', index=False)
